# %% [markdown]
# # Measuring the Hubble Constant (H₀) with Type Ia Supernovae
#
# **A hands-on tutorial: frequentist and Bayesian approaches**
#
# This notebook walks you through estimating the Hubble constant, $H_0$, from low-redshift Type Ia Supernovae (SNe Ia). We'll:
#
# 1. Review the low-$z$ Hubble-law approximation and the SN distance-modulus relation.
# 2. Generate a realistic synthetic SN sample (or load your own data).
# 3. Estimate $H_0$ with a frequentist $\chi^2$ fit, including bootstrap uncertainty.
# 4. Do Maximum-Likelihood estimator for another frequentist approach.
# 4. Do a Bayesian inference on a grid with sensible priors, and marginalize to obtain $p(H_0\,|\,\mathrm{data})$ (no Cobaya, emcee, Nautilus or any other famous sampler!)
# 5. Visualize the Hubble diagram, residuals, likelihoods, and posteriors.
#
# The tutorial keeps the cosmology deliberately simple and focuses on the statistics. For real analyses you would:
# - Use calibrated absolute magnitudes from independent distance ladders (e.g., Cepheids, TRGB).
# - Model peculiar-velocity and selection effects carefully.
# - Use full cosmological luminosity distances for higher redshifts.
#
# ---
# **Key low-$z$ relations** (valid for $z\lesssim0.1$):
#
# $$ d_L \approx \frac{cz}{H_0} \quad (\text{in Mpc}) $$
# $$ \mu \equiv m - M = 5\log_{10}\!\left( \frac{d_L}{\text{Mpc}} \right) + 25 $$
# Combining these:
# $$ m = M + 5\log_{10}(cz) - 5\log_{10}(H_0) + 25. $$
#
# If $M$ is known (from external calibration), one can directly infer $H_0$. If $M$ is unknown **and** you only fit SN data, then $(M, H_0)$ are nearly perfectly degenerate at low $z$—you must supply an $M$ prior or external constraint to break the degeneracy.

# %% [markdown]
# ## 0) Imports and utilities

# %%
import numpy as np
import matplotlib.pyplot as plt
from dataclasses import dataclass
from typing import Tuple

c_km_s = 299792.458  # speed of light in km/s

def mu_from_z(z, H0):
    """Low-z luminosity distance modulus: mu = 5 log10(c z / H0 [Mpc]) + 25.
    Here c is in km/s, H0 in km/s/Mpc, so cz/H0 is in Mpc.
    """
    dL_Mpc = (c_km_s * z) / H0
    return 5.0 * np.log10(dL_Mpc) + 25.0

def mag_model(z, H0, M):
    return M + mu_from_z(z, H0)

def sigma_mu_pec(z, v_pec=300.0, H0=70.0):
    """Approximate magnitude uncertainty from peculiar velocities.
    sigma_mu ~ (5/ln(10)) * (sigma_dL/dL).
    At low z, dL ~ cz/H0, so fractional distance error from peculiar velocity sigma_v is ~ sigma_v/(cz).
    """
    frac = v_pec/(c_km_s * z)
    return (5/np.log(10)) * frac

@dataclass
class SNSample:
    z: np.ndarray
    m: np.ndarray
    sigma_m: np.ndarray
    name: str = "synthetic"

def make_synthetic_sample(N=100, H0=73.0, M=-19.3, zmin=0.01, zmax=0.08,
                          sigma_meas=0.1, sigma_int=0.1, v_pec=300.0, rng=None) -> SNSample:
    rng = np.random.default_rng(rng)
    z = np.sort(rng.uniform(zmin, zmax, size=N))
    mu = mu_from_z(z, H0)
    m_true = M + mu
    # per-SN error budget: measurement + peculiar velocity + intrinsic scatter
    sig_pec = sigma_mu_pec(z, v_pec=v_pec, H0=H0)
    sigma_tot = np.sqrt(sigma_meas**2 + sig_pec**2 + sigma_int**2)
    m_obs = rng.normal(m_true, sigma_tot)
    return SNSample(z=z, m=m_obs, sigma_m=sigma_tot, name="synthetic")

def chi2(H0, M, sn: SNSample):
    model = mag_model(sn.z, H0, M)
    return np.sum(((sn.m - model)/sn.sigma_m)**2)

def best_fit_H0_given_M(sn: SNSample, M, H0_grid=np.linspace(50, 90, 801)):
    chi2_vals = np.array([chi2(H0, M, sn) for H0 in H0_grid])
    j = np.argmin(chi2_vals)
    return H0_grid[j], chi2_vals, H0_grid

def conf_interval_from_delta_chi2(H0_grid, chi2_vals, dof=1, delta=1.0):
    # For 1 parameter, Delta chi^2 = 1 gives ~68% CI.
    j = np.argmin(chi2_vals)
    chi2_min = chi2_vals[j]
    mask = chi2_vals <= chi2_min + delta
    H0_in = H0_grid[mask]
    return H0_grid[j], H0_in.min(), H0_in.max()

def bootstrap_H0(sn: SNSample, M, nboot=500, rng=None):
    """
    Estimate the uncertainty in H0 by bootstrapping the SN sample.

    Parameters
    ----------
    sn : SNSample
        The supernova sample (with z, m, sigma_m arrays).
    M : float
        The assumed absolute magnitude of the supernovae.
    nboot : int, optional
        Number of bootstrap resamples (default: 500).
    rng : np.random.Generator or None, optional
        Random number generator or seed (default: None).

    Returns
    -------
    np.ndarray
        Array of best-fit H0 values from each bootstrap resample.
    """
    rng = np.random.default_rng(rng)
    H0s = []
    idx = np.arange(len(sn.z))
    H0_grid = np.linspace(50, 90, 801) # same grid as before
    for _ in range(nboot):
        # Resample SN indices with replacement
        sel = rng.choice(idx, size=len(idx), replace=True)
        # Create a new SNSample with the resampled data
        sn_b = SNSample(sn.z[sel], sn.m[sel], sn.sigma_m[sel], name=sn.name)
        # Find best-fit H0 for this resample
        hbest, chi2_vals, Hg = best_fit_H0_given_M(sn_b, M, H0_grid=H0_grid)
        H0s.append(hbest)
    return np.array(H0s)

def bayes_grid_posterior(sn: SNSample,
                         H0_grid=np.linspace(50, 90, 801),
                         M_grid=np.linspace(-19.6, -19.0, 601),
                         prior_H0=lambda h: 1.0,  # flat
                         prior_M=lambda m: 1.0):  # flat or normal
    # Gaussian log-likelihood
    HH, MM = np.meshgrid(H0_grid, M_grid, indexing='xy')
    loglike = np.zeros_like(HH)
    for i in range(len(sn.z)):
        model = mag_model(sn.z[i], HH, MM)
        loglike += -0.5 * ((sn.m[i]-model)/sn.sigma_m[i])**2 - np.log(sn.sigma_m[i])
    # add log-priors
    # H0 prior
    logp_H0 = np.log(np.vectorize(prior_H0)(H0_grid))
    logp_M  = np.log(np.vectorize(prior_M)(M_grid))
    logpost = loglike + logp_H0[None, :] + logp_M[:, None]
    # stabilize
    m = np.max(logpost)
    post = np.exp(logpost - m)
    post /= np.trapz(np.trapz(post, H0_grid, axis=1), M_grid, axis=0)
    # marginals
    p_H0 = np.trapz(post, M_grid, axis=0)
    p_M  = np.trapz(post, H0_grid, axis=1)
    return {
        'H0_grid': H0_grid,
        'M_grid': M_grid,
        'post_2d': post,
        'p_H0': p_H0,
        'p_M': p_M,
    }

def credible_interval_from_pdf(x, p, alpha=0.68):
    # Highest Posterior Density (HPD) via simple threshold search
    p = p/np.trapz(p, x)
    idx = np.argsort(p)[::-1]
    csum = np.cumsum(p[idx])*(x[1]-x[0])
    k = np.searchsorted(csum, alpha)
    thr = p[idx[k]]
    sel = p >= thr
    xs = x[sel]
    return xs.min(), xs.max()

# %% [markdown]
# ## 1) Generate a synthetic low-\(z\) SN sample (or load your own)
#
# To keep the notebook self-contained, we'll create a mock dataset with a true $H_0$ and $M$. You can swap in your own data later. The generated magnitudes include measurement noise, intrinsic scatter, and a redshift-dependent peculiar-velocity uncertainty.

# %%
true_H0 = 73.0  # km/s/Mpc
true_M  = -19.3 # absolute magnitude
sn = make_synthetic_sample(N=200, H0=true_H0, M=true_M, rng=None)
print(f"Synthetic sample: {len(sn.z)} SNe ({sn.name}) generated!")
# Out:
# Synthetic sample: 200 SNe (synthetic) generated!

# %% [markdown]
# ### Visualize the Hubble diagram

# %%
plt.figure(figsize=(8, 5))
plt.errorbar(sn.z, sn.m, yerr=sn.sigma_m, fmt='o', alpha=0.5, color='cornflowerblue', 
             ecolor='grey', elinewidth=2, capsize=3, label='Synthetic SNe')
zz = np.linspace(sn.z.min()*0.8, sn.z.max()*1.2, 400)
plt.plot(zz, mag_model(zz, true_H0, true_M), color='crimson', lw=2.5, label='True model')
plt.xlabel('Redshift $z$', fontsize=13)
plt.ylabel('Apparent magnitude $m$', fontsize=13)
plt.title('Hubble Diagram (Synthetic Data)', fontsize=15, fontweight='bold')
plt.grid(True, which='both', ls='--', alpha=0.3)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2a) Frequentist: $\chi^2$ fit for $H_0$ (assuming $M$ is known)
#
# Because $M$ and $H_0$ are degenerate for SN-only data, we first assume $M$ is known from an external calibration (distance ladder). We'll scan over $H_0$, compute $\chi^2$, find the minimum, and take the $\Delta\chi^2=1$ interval as an approximate 68% confidence interval for 1 parameter.

# %%
M_known = -19.3  # pretend we know this from a calibrator sample
H0_grid = np.linspace(50, 90, 1000000)
H0_best, chi2_vals, Hg = best_fit_H0_given_M(sn, M_known, H0_grid=H0_grid)
H0_min, H0_lo, H0_hi = conf_interval_from_delta_chi2(Hg, chi2_vals, dof=1, delta=1.0)
print(f"Frequentist best-fit H0 = {H0_min:.2f} km/s/Mpc")
print(f"68% CI (Delta chi^2=1): [{H0_lo:.2f}, {H0_hi:.2f}] km/s/Mpc")

plt.figure(figsize=(8, 5))
plt.plot(Hg, chi2_vals, color='royalblue', lw=2, label=r'$\chi^2(H_0)$')
plt.axvline(H0_min, color='crimson', linestyle='--', lw=2, label=fr'Best-fit $H_0$ = {H0_min:.2f}')
plt.axhline(chi2_vals.min()+1.0, color='green', linestyle=':', lw=2, label=r'$\Delta\chi^2=1$ (68% CI)')
plt.fill_betweenx([chi2_vals.min(), chi2_vals.min()+1.0], H0_lo, H0_hi, color='lime', alpha=0.2, label='68% CI')
plt.xlabel(r'$H_0$ [km/s/Mpc]', fontsize=13)
plt.ylabel(r'$\chi^2(H_0)$', fontsize=13)
plt.title(r'Frequentist scan over $H_0$ ($M$ fixed)', fontsize=15, fontweight='bold')
plt.xlim(72, 75)
plt.ylim(chi2_vals.min() - 1, chi2_vals.min() + 10)
plt.grid(True, ls='--', alpha=0.3)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# Frequentist best-fit H0 = 73.04 km/s/Mpc
# 68% CI (Delta chi^2=1): [72.66, 73.41] km/s/Mpc

# %% [markdown]
# ### Residuals and goodness-of-fit checks
# With the frequentist best-fit $H_0$ (and fixed $M$), inspect residuals.

# %%
model_best = mag_model(sn.z, H0_min, M_known)
res = sn.m - model_best
plt.figure()
plt.scatter(sn.z, res, alpha=0.4)
plt.axhline(0.0, color='black')
plt.xlabel('z')
plt.ylabel('Residual m - model')
plt.title('Residuals vs z (Frequentist best-fit H0)')
plt.show()

nu = len(sn.z) - 1  # 1 parameter (H0) fitted here
chi2_min = np.min(chi2_vals)
print(f"Reduced chi^2 ~ {chi2_min/nu:.2f} (nu={nu})")
# Out:
# Reduced chi^2 ~ 1.11 (nu=199)

# %% [markdown]
# ### Bootstrap uncertainty (non-parametric)
#
# We can also estimate the sampling distribution of $\hat H_0$ by bootstrapping SNe with replacement.

# %%
import seaborn as sns

H0_boot = bootstrap_H0(sn, M_known, nboot=2000, rng=42)
h_med = np.median(H0_boot)
h_lo, h_hi = np.percentile(H0_boot, [16, 84])
print(f"Bootstrap median H0 = {h_med:.2f} km/s/Mpc")
print(f"Bootstrap 68% interval: [{h_lo:.2f}, {h_hi:.2f}] km/s/Mpc")

plt.figure()
sns.histplot(H0_boot, bins=30, kde=True, stat="count", color="skyblue", edgecolor="k")
plt.axvline(H0_min, color='r', linestyle='--', label=f'Best-fit H0 = {H0_min:.2f}')
plt.xlabel('H0 [km/s/Mpc]')
plt.ylabel('Count')
plt.title('Bootstrap distribution of H0 (M fixed)')
plt.legend()
plt.show()
# Out:
# Bootstrap median H0 = 73.05 km/s/Mpc
# Bootstrap 68% interval: [72.65, 73.45] km/s/Mpc

# %% [markdown]
# ### Measurements in agreement... or not?
#
# Given the sampled distribution, we can discuss if two measurements are in agreement with each other or not.

# %%
# Example reference value for comparison, e.g. Planck H0
H0_ref = 67.0  # km/s/Mpc (replace with whatever you want to test against)

# %%
# OPTION 1: counting

# Fraction of bootstrap samples more extreme than |diff|
diff_obs = abs(h_med - H0_ref)
p_value = np.mean(abs(H0_boot - h_med) >= diff_obs)

print(f"Reference H0 = {H0_ref:.2f} km/s/Mpc")
print(f"Observed median H0 = {h_med:.2f} km/s/Mpc")
print(f"Fraction of bootstrap samples more extreme than the difference between two values = {p_value:.4f}")
# Out:
# Reference H0 = 67.00 km/s/Mpc
# Observed median H0 = 73.05 km/s/Mpc
# Fraction of bootstrap samples more extreme than the difference between two values = 0.0000

# %%
# OPTION 2: using proper integration of the probability distribution
from scipy.stats import gaussian_kde

# Build a smooth PDF from bootstrap samples
kde = gaussian_kde(H0_boot)

# Define a fine grid covering the distribution
x_vals = np.linspace(min(H0_boot), max(H0_boot), 2000)
pdf_vals = kde(x_vals)

# Normalize PDF (should already be normalized, but just to be safe)
pdf_vals /= np.trapz(pdf_vals, x_vals)

# CDF by cumulative integration --> this is your chi2 distribution!!!
cdf_vals = np.cumsum(pdf_vals) * (x_vals[1] - x_vals[0])

# Find the CDF value at H0_ref
cdf_ref = np.interp(H0_ref, x_vals, cdf_vals)

# Two-sided p-value = probability mass outside as extreme as ref
if H0_ref < h_med:
    p_value = 2 * cdf_ref
else:
    p_value = 2 * (1 - cdf_ref)

print(f"Reference H0 = {H0_ref:.2f} km/s/Mpc")
print(f"Bootstrap median H0 = {h_med:.2f} km/s/Mpc")
print(f"p-value (from KDE integration) = {p_value:.4f}")
# Out:
# Reference H0 = 67.00 km/s/Mpc
# Bootstrap median H0 = 73.05 km/s/Mpc
# p-value (from KDE integration) = 0.0000

# %% [markdown]
# ---
# ## 2b) Frequentist MLE: joint fit of $(H_0, M)$ with an external calibrator
#
# SN-only data at low $z$ cannot separately determine $H_0$ and $M$; they are (almost) perfectly degenerate. In a frequentist setting, we can include an **external calibrator measurement** of $M$ via a Gaussian constraint (a.k.a. penalty term) and then do **maximum likelihood estimation (MLE)** jointly for $(H_0, M)$.
#
# We minimize
# $$ -2\ln\mathcal{L}(H_0, M) = \chi^2_\mathrm{SN}(H_0, M) + \frac{(M-M_\mathrm{cal})^2}{\sigma_M^2}. $$
#
# From the MLE, we compute the **covariance** and **correlation** matrices using a numerical Hessian approximation to the observed Fisher information.

# %%
def nll_sn(H0, M, sn):
    # Gaussian -2 log L = chi^2 + const (const dropped)
    return chi2(H0, M, sn)

def nll_total(H0, M, sn, M_cal=-19.3, M_sigma=0.05):
    pen = ((M - M_cal)/M_sigma)**2
    return nll_sn(H0, M, sn) + pen

def nelder_mead_2d(fun, x0, args=(), maxit=2000, tol=1e-6):
    # Minimal Nelder–Mead for 2D without scipy; good enough for smooth problems.
    import numpy as np
    alpha, gamma, rho, sigma = 1.0, 2.0, 0.5, 0.5
    x = np.array(x0, dtype=float)
    # initial simplex
    s = np.array([x, x + np.array([1.0, 0.0]), x + np.array([0.0, 1.0])])
    f = np.array([fun(s[i], *args) for i in range(3)])
    it = 0
    while it < maxit:
        idx = np.argsort(f)
        s, f = s[idx], f[idx]
        best, worst = s[0], s[-1]
        if np.max(np.abs(s - s[0])) < tol and np.max(np.abs(f - f[0])) < tol:
            break
        centroid = (s[0] + s[1])/2.0
        xr = centroid + alpha*(centroid - s[2])
        fr = fun(xr, *args)
        if f[0] <= fr < f[1]:
            s[2], f[2] = xr, fr
        elif fr < f[0]:
            xe = centroid + gamma*(xr - centroid)
            fe = fun(xe, *args)
            if fe < fr:
                s[2], f[2] = xe, fe
            else:
                s[2], f[2] = xr, fr
        else:
            xc = centroid + rho*(s[2] - centroid)
            fc = fun(xc, *args)
            if fc < f[2]:
                s[2], f[2] = xc, fc
            else:
                # shrink
                s[1] = s[0] + sigma*(s[1]-s[0])
                s[2] = s[0] + sigma*(s[2]-s[0])
                f[1] = fun(s[1], *args)
                f[2] = fun(s[2], *args)
        it += 1
    return s[0], f[0]

def num_hessian_2d(fun, x, args=(), eps=1e-4):
    # Central finite-difference Hessian for 2D function
    x = np.array(x, dtype=float)
    e1 = np.array([eps, 0.0])
    e2 = np.array([0.0, eps])
    fpp = fun(x + e1 + e2, *args)
    fpm = fun(x + e1 - e2, *args)
    fmp = fun(x - e1 + e2, *args)
    fmm = fun(x - e1 - e2, *args)
    f00 = fun(x, *args)
    fpp1 = fun(x + e1, *args)
    fmm1 = fun(x - e1, *args)
    fpp2 = fun(x + e2, *args)
    fmm2 = fun(x - e2, *args)
    H11 = (fpp1 - 2*f00 + fmm1)/(eps**2)
    H22 = (fpp2 - 2*f00 + fmm2)/(eps**2)
    H12 = (fpp - fpm - fmp + fmm)/(4*eps**2)
    H = np.array([[H11, H12], [H12, H22]])
    return H

# Run MLE with Gaussian calibrator on M
M_cal, M_sigma = -19.3, 0.05
x_mle, fval = nelder_mead_2d(lambda v, *args: nll_total(v[0], v[1], *args),
                             x0=(70.0, -19.3), args=(sn, M_cal, M_sigma))
H0_mle, M_mle = x_mle
print(f"MLE (with calibrator): H0 = {H0_mle:.3f}, M = {M_mle:.3f}")

# Covariance and correlation from Hessian
H = num_hessian_2d(lambda v, *args: nll_total(v[0], v[1], *args), x_mle, args=(sn, M_cal, M_sigma))
Cov = np.linalg.inv(H)
sig_H0 = np.sqrt(Cov[0,0])
sig_M  = np.sqrt(Cov[1,1])
corr = Cov / np.outer([sig_H0, sig_M], [sig_H0, sig_M])
print("Covariance matrix (H0, M):\n", Cov)
print("Correlation matrix (H0, M):\n", corr)

H0_grid = np.linspace(H0_mle-6, H0_mle+6, 200)
M_grid  = np.linspace(M_mle-0.3, M_mle+0.3, 200)
X, Y = np.meshgrid(H0_grid, M_grid, indexing='xy')

d = np.stack([(X-H0_mle).ravel(), (Y-M_mle).ravel()], axis=0)
quad = np.einsum('ij,jk,ki->i', d.T, H, d).reshape(X.shape)

plt.figure()
cs = plt.contour(
    X, Y, quad,
    levels=[2.30, 6.17],          # 1σ and 2σ levels
    linestyles=['solid','dashed'],
    colors=['darkorchid', 'pink']        # set contour colors
)

plt.xlabel('H0 [km/s/Mpc]')
plt.ylabel('M [mag]')
plt.title('MLE: 1σ/2σ error contours (Hessian approx)')
plt.show()
# Out:
# MLE (with calibrator): H0 = 73.036, M = -19.300
# Covariance matrix (H0, M):
#  [[1.48301357e+00 4.20247173e-02]
#  [4.20247173e-02 1.24949255e-03]]
# Correlation matrix (H0, M):
#  [[1.         0.97625979]
#  [0.97625979 1.        ]]

# %% [markdown]
# ## 3) Bayesian analysis on a grid
#
# Now, let's assume that we are solving this problem from a Bayesian approach. We know few things: the model, and some prior information about absolute magnitude $M$. We assume that $H_0$ and $M$ have probability density distributions, s we can now place priors on $(H_0, M)$ and compute the joint posterior on a 2D grid. We'll then marginalize to obtain $p(H_0\,|\,\mathrm{data})$.
#
# Two common scenarios:
# 1. **Calibrated $M$**: adopt a Gaussian prior for $M$ centered on an external calibration with known uncertainty.
# 2. **Uncalibrated $M$**: adopt a weak/flat prior on $M$, showing the degeneracy.
#
# Below we demonstrate the *calibrated* case by using a Gaussian prior for $M$ with $\sigma_M=0.05\,\mathrm{mag}$.

# %%
H0_grid = np.linspace(50, 90, 2000)
M_grid  = np.linspace(-19.6, -19.0, 2000)

M_mean, M_sigma = -19.3, 0.05
def prior_H0(h):
    return 1.0 if (50<=h<=90) else 0.0  # flat within bounds, this is what we call a Uniform prior
def prior_M(m):
    # Gaussian prior (calibrator)
    return np.exp(-0.5*((m-M_mean)/M_sigma)**2)

post = bayes_grid_posterior(sn, H0_grid=H0_grid, M_grid=M_grid,
                            prior_H0=prior_H0, prior_M=prior_M)
pH0 = post['p_H0']/np.trapz(post['p_H0'], H0_grid)
h_lo, h_hi = credible_interval_from_pdf(H0_grid, pH0, alpha=0.68)
h_mean = np.trapz(H0_grid*pH0, H0_grid)
print(f"Bayesian calibrated case: E[H0] ≈ {h_mean:.2f} km/s/Mpc")
print(f"Bayesian 68% HPD ~ [{h_lo:.2f}, {h_hi:.2f}] km/s/Mpc")

plt.figure()
plt.plot(H0_grid, pH0, label='Posterior p(H0 | data)')
plt.axvline(h_mean, color='r', linestyle='--', label=f'Mean H0 = {h_mean:.2f}')
plt.axvline(h_lo, color='g', linestyle=':', label=f'68% HPD [{h_lo:.2f}, {h_hi:.2f}]')
plt.axvline(h_hi, color='g', linestyle=':')
plt.xlabel('H0 [km/s/Mpc]')
plt.ylabel('Posterior p(H0 | data)')
plt.title('Bayesian posterior for H0 (Gaussian prior on M)')
plt.legend()
plt.show()
# Out:
# Bayesian calibrated case: E[H0] ≈ 73.10 km/s/Mpc
# Bayesian 68% HPD ~ [71.35, 74.77] km/s/Mpc

# %%
# Normalize posterior to unit maximum
pH0 /= pH0.max()

# Bootstrap histogram with KDE also normalized to unit max
plt.figure()
sns.histplot(
    H0_boot, bins=30, kde=True,
    stat="density", color="skyblue", 
    label='Bootstrap samples'
)

# Rescale histogram density to unit maximum
counts, bins = np.histogram(H0_boot, bins=30, density=True)
scale_factor = counts.max()
plt.plot(H0_grid, pH0 * scale_factor, color='orange', lw=2, label='Bayesian posterior p(H0 | data)')

#plt.axvline(h_mean, color='r', linestyle='--', label=f'Mean H0 = {h_mean:.2f}')
#plt.axvline(h_lo, color='g', linestyle=':', label=f'68% HPD [{h_lo:.2f}, {h_hi:.2f}]')
#plt.axvline(h_hi, color='g', linestyle=':')

plt.xlabel('H0 [km/s/Mpc]')
plt.ylabel('Density (scaled)')
plt.title('Comparison of Bootstrap and Bayesian Posterior (same height)')
plt.xlim(68, 78)
plt.legend()
plt.show()

# %% [markdown]
# ### Inspect the 2D joint posterior

# %%
plt.figure(figsize=(8, 6))
X, Y = np.meshgrid(H0_grid, M_grid, indexing='xy')
Z = post['post_2d']
cs = plt.contour(X, Y, Z, levels=np.linspace(Z.max()*0.1, Z.max()*0.9, 5), cmap='plasma')
plt.clabel(cs, inline=True, fontsize=9)
plt.xlabel(r'$H_0$ [km/s/Mpc]', fontsize=13)
plt.ylabel(r'$M$ [mag]', fontsize=13)
plt.title('Joint Posterior: $H_0$ vs $M$', fontsize=15, fontweight='bold')
plt.xlim(68, 80)
plt.ylim(-19.5, -19.1)
plt.grid(alpha=0.2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Optional: uncalibrated $M$ (flat prior) to show degeneracy
# Set a broad, nearly flat prior on $M$ and see how the $H_0$ marginal becomes wide.

# %%
def prior_M_flat(m):
    return 1.0 if (-19.6 <= m <= -19.0) else 0.0
post_uncal = bayes_grid_posterior(sn, H0_grid=H0_grid, M_grid=M_grid,
                                  prior_H0=prior_H0, prior_M=prior_M_flat)
pH0_uncal = post_uncal['p_H0']/np.trapz(post_uncal['p_H0'], H0_grid)
plt.figure()
plt.plot(H0_grid, pH0_uncal)
plt.xlabel('H0 [km/s/Mpc]')
plt.ylabel('Posterior p(H0 | data)')
plt.title('Bayesian posterior for H0 (flat prior on M → degeneracy)')
plt.show()

# %%
plt.figure(figsize=(8, 6))
X, Y = np.meshgrid(H0_grid, M_grid, indexing='xy')
Z = post_uncal['post_2d']
cs = plt.contour(X, Y, Z, levels=np.linspace(Z.max()*0.1, Z.max()*0.9, 5), cmap='plasma')
plt.clabel(cs, inline=True, fontsize=9)
plt.xlabel(r'$H_0$ [km/s/Mpc]', fontsize=13)
plt.ylabel(r'$M$ [mag]', fontsize=13)
plt.title('Joint Posterior: $H_0$ vs $M$ --> DEGENERATED!', fontsize=15, fontweight='bold')
plt.grid(alpha=0.2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4) Bayesian approach with Cobaya
#
# In the previous section, we have investigated how the posterior for ($H_0$, $M$) looks like by sampling (evaluating) in a simple grid.
#
# Now, we are going to use Cobaya to properly sample using its `mcmc` method.

# %%
def loglike_cobaya(H0, M):
    return -0.5 * chi2(H0, M, sn)

info_dict = {
    'params': {
        'H0': {'prior': {'min': 50, 'max': 90}, 'latex': r'H_0'},
        'M':  {"prior": {"dist": "norm", "loc": -19.3, "scale": 0.05}, 'latex': r'M'},
    },
    'likelihood': {
        'my_sn_likelihood': {
            'external': loglike_cobaya,        }
    },
    'sampler': {'mcmc': {'max_tries': 100000, 'Rminus1_stop': 0.001}}}

# %%
from cobaya.run import run

updated_info, sampler = run(info_dict)
# Out:
# [my_sn_likelihood] Initialized external likelihood.
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [mcmc] Initial point: H0:74.45744, M:-19.22801
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {my_sn_likelihood: 36900.0}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Sampling!
# [mcmc] Progress @ 2025-08-28 09:52:32 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.054
# [mcmc]  - Convergence of means: R-1 = 0.956119 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.125
# [mcmc]  - Convergence of means: R-1 = 0.328166 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.187
# [mcmc]  - Convergence of means: R-1 = 0.083820 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.268
# [mcmc]  - Convergence of means: R-1 = 0.070886 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.044856 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.312
# [mcmc]  - Convergence of means: R-1 = 0.026720 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.034820 after 448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.292
# [mcmc]  - Convergence of means: R-1 = 0.037983 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.290
# [mcmc]  - Convergence of means: R-1 = 0.012784 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.291
# [mcmc]  - Convergence of means: R-1 = 0.022983 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.018008 after 704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.023036 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1040 samples accepted.
# [mcmc]  - Acceptance rate: 0.291
# [mcmc]  - Convergence of means: R-1 = 0.011120 after 832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.005950 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.008226 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.029920 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1360 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.033777 after 1088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.020698 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1520 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.008728 after 1216 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1600 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.012301 after 1280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1680 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.026970 after 1344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.019183 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1840 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.013165 after 1472 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.006410 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2000 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.005097 after 1600 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2080 samples accepted.
# [mcmc]  - Acceptance rate: 0.305
# [mcmc]  - Convergence of means: R-1 = 0.007276 after 1664 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2160 samples accepted.
# [mcmc]  - Acceptance rate: 0.306
# [mcmc]  - Convergence of means: R-1 = 0.003491 after 1728 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2240 samples accepted.
# [mcmc]  - Acceptance rate: 0.306
# [mcmc]  - Convergence of means: R-1 = 0.007515 after 1792 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2320 samples accepted.
# [mcmc]  - Acceptance rate: 0.308
# [mcmc]  - Convergence of means: R-1 = 0.008889 after 1856 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2400 samples accepted.
# [mcmc]  - Acceptance rate: 0.306
# [mcmc]  - Convergence of means: R-1 = 0.012787 after 1920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2480 samples accepted.
# [mcmc]  - Acceptance rate: 0.308
# [mcmc]  - Convergence of means: R-1 = 0.008009 after 1984 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2560 samples accepted.
# [mcmc]  - Acceptance rate: 0.308
# [mcmc]  - Convergence of means: R-1 = 0.003461 after 2048 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2640 samples accepted.
# [mcmc]  - Acceptance rate: 0.309
# [mcmc]  - Convergence of means: R-1 = 0.005327 after 2112 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2720 samples accepted.
# [mcmc]  - Acceptance rate: 0.310
# [mcmc]  - Convergence of means: R-1 = 0.006622 after 2176 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2800 samples accepted.
# [mcmc]  - Acceptance rate: 0.308
# [mcmc]  - Convergence of means: R-1 = 0.005880 after 2240 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2880 samples accepted.
# [mcmc]  - Acceptance rate: 0.307
# [mcmc]  - Convergence of means: R-1 = 0.006719 after 2304 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2960 samples accepted.
# [mcmc]  - Acceptance rate: 0.307
# [mcmc]  - Convergence of means: R-1 = 0.005917 after 2368 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3040 samples accepted.
# [mcmc]  - Acceptance rate: 0.308
# [mcmc]  - Convergence of means: R-1 = 0.004273 after 2432 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3120 samples accepted.
# [mcmc]  - Acceptance rate: 0.307
# [mcmc]  - Convergence of means: R-1 = 0.003032 after 2496 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3200 samples accepted.
# [mcmc]  - Acceptance rate: 0.307
# [mcmc]  - Convergence of means: R-1 = 0.005709 after 2560 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3280 samples accepted.
# [mcmc]  - Acceptance rate: 0.307
# [mcmc]  - Convergence of means: R-1 = 0.003690 after 2624 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3360 samples accepted.
# [mcmc]  - Acceptance rate: 0.308
# [mcmc]  - Convergence of means: R-1 = 0.004651 after 2688 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3440 samples accepted.
# [mcmc]  - Acceptance rate: 0.306
# [mcmc]  - Convergence of means: R-1 = 0.002496 after 2752 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3520 samples accepted.
# [mcmc]  - Acceptance rate: 0.306
# [mcmc]  - Convergence of means: R-1 = 0.001602 after 2816 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3600 samples accepted.
# [mcmc]  - Acceptance rate: 0.306
# [mcmc]  - Convergence of means: R-1 = 0.002248 after 2880 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3680 samples accepted.
# [mcmc]  - Acceptance rate: 0.305
# [mcmc]  - Convergence of means: R-1 = 0.001972 after 2944 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3760 samples accepted.
# [mcmc]  - Acceptance rate: 0.307
# [mcmc]  - Convergence of means: R-1 = 0.002314 after 3008 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3840 samples accepted.
# [mcmc]  - Acceptance rate: 0.305
# [mcmc]  - Convergence of means: R-1 = 0.003213 after 3072 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3920 samples accepted.
# [mcmc]  - Acceptance rate: 0.305
# [mcmc]  - Convergence of means: R-1 = 0.003052 after 3136 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4000 samples accepted.
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.004808 after 3200 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4080 samples accepted.
# [mcmc]  - Acceptance rate: 0.305
# [mcmc]  - Convergence of means: R-1 = 0.003249 after 3264 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4160 samples accepted.
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.001935 after 3328 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4240 samples accepted.
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.003145 after 3392 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4320 samples accepted.
# [mcmc]  - Acceptance rate: 0.305
# [mcmc]  - Convergence of means: R-1 = 0.003856 after 3456 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4400 samples accepted.
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.003794 after 3520 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4480 samples accepted.
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.002629 after 3584 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4560 samples accepted.
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.001141 after 3648 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4640 samples accepted.
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.002515 after 3712 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4720 samples accepted.
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.001854 after 3776 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4800 samples accepted.
# [mcmc]  - Acceptance rate: 0.303
# [mcmc]  - Convergence of means: R-1 = 0.001543 after 3840 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4880 samples accepted.
# [mcmc]  - Acceptance rate: 0.303
# [mcmc]  - Convergence of means: R-1 = 0.002017 after 3904 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4960 samples accepted.
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.002478 after 3968 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5040 samples accepted.
# [mcmc]  - Acceptance rate: 0.305
# [mcmc]  - Convergence of means: R-1 = 0.004735 after 4032 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5120 samples accepted.
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.004055 after 4096 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5200 samples accepted.
# [mcmc]  - Acceptance rate: 0.303
# [mcmc]  - Convergence of means: R-1 = 0.005070 after 4160 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5280 samples accepted.
# [mcmc]  - Acceptance rate: 0.303
# [mcmc]  - Convergence of means: R-1 = 0.003877 after 4224 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5360 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.004526 after 4288 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5440 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.004758 after 4352 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5520 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.003524 after 4416 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5600 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.003683 after 4480 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5680 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.002873 after 4544 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5760 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.003597 after 4608 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5840 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.004152 after 4672 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5920 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.004979 after 4736 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6000 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.004384 after 4800 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6080 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.005230 after 4864 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6160 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.005376 after 4928 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6240 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.006006 after 4992 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6320 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.005490 after 5056 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6400 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.007619 after 5120 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6480 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.007535 after 5184 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6560 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.007698 after 5248 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6640 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.008320 after 5312 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6720 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.009409 after 5376 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6800 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.007732 after 5440 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6880 samples accepted.
# [mcmc]  - Acceptance rate: 0.297
# [mcmc]  - Convergence of means: R-1 = 0.007986 after 5504 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6960 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.006087 after 5568 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7040 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.005468 after 5632 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7120 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.005258 after 5696 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7200 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.005606 after 5760 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7280 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.004921 after 5824 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7360 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.005168 after 5888 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7440 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.005385 after 5952 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7520 samples accepted.
# [mcmc]  - Acceptance rate: 0.297
# [mcmc]  - Convergence of means: R-1 = 0.004425 after 6016 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7600 samples accepted.
# [mcmc]  - Acceptance rate: 0.297
# [mcmc]  - Convergence of means: R-1 = 0.004456 after 6080 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7680 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.005079 after 6144 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7760 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.005616 after 6208 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7840 samples accepted.
# [mcmc]  - Acceptance rate: 0.297
# [mcmc]  - Convergence of means: R-1 = 0.005790 after 6272 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7920 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.004763 after 6336 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8000 samples accepted.
# [mcmc]  - Acceptance rate: 0.297
# [mcmc]  - Convergence of means: R-1 = 0.004130 after 6400 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8080 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.003847 after 6464 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8160 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.003597 after 6528 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8240 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.003549 after 6592 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8320 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.004040 after 6656 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8400 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.004343 after 6720 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8480 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.003447 after 6784 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8560 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.004125 after 6848 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8640 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.003569 after 6912 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8720 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.003177 after 6976 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8800 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.003002 after 7040 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8880 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.003457 after 7104 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8960 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.003772 after 7168 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9040 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.003122 after 7232 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9120 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.002382 after 7296 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9200 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.002601 after 7360 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9280 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.002670 after 7424 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9360 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.002161 after 7488 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9440 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.002622 after 7552 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9520 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.002613 after 7616 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9600 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.002674 after 7680 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9680 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.002536 after 7744 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9760 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.003142 after 7808 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9840 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.003522 after 7872 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9920 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.003551 after 7936 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10000 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.004310 after 8000 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10080 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.004370 after 8064 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10160 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.005263 after 8128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10240 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.004754 after 8192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10320 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.004723 after 8256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10400 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.004801 after 8320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10480 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.003848 after 8384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10560 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.003809 after 8448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10640 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.003426 after 8512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10720 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.003696 after 8576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10800 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.004088 after 8640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10880 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.004145 after 8704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10960 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.003562 after 8768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11040 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.004134 after 8832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11120 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.004050 after 8896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11200 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.004465 after 8960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11280 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.004053 after 9024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11360 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.003522 after 9088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11440 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.004069 after 9152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11520 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.003772 after 9216 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11600 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.003721 after 9280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11680 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.003482 after 9344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11760 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.003348 after 9408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11840 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.003322 after 9472 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11920 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.002948 after 9536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12000 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.002719 after 9600 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12080 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.001977 after 9664 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12160 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.001785 after 9728 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12240 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.002133 after 9792 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12320 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.002206 after 9856 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12400 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.002534 after 9920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12480 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.001903 after 9984 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12560 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.002097 after 10048 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12640 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.001902 after 10112 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12720 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.001937 after 10176 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12800 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.002684 after 10240 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12880 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.002306 after 10304 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12960 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.002253 after 10368 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13040 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.002240 after 10432 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13120 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.002274 after 10496 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13200 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.001990 after 10560 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13280 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.002196 after 10624 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13360 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.002370 after 10688 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13440 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.002363 after 10752 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13520 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.001689 after 10816 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13600 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.002010 after 10880 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13680 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.001630 after 10944 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13760 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.001674 after 11008 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13840 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.001480 after 11072 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13920 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.001309 after 11136 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14000 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.001062 after 11200 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14080 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.000965 after 11264 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14160 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.001268 after 11328 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14240 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.001303 after 11392 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14320 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.001349 after 11456 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14400 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.001387 after 11520 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14480 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.001150 after 11584 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14560 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.001322 after 11648 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14640 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.001219 after 11712 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14720 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.001341 after 11776 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14800 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.001282 after 11840 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14880 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.001352 after 11904 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14960 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.001317 after 11968 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15040 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.001306 after 12032 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15120 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.001348 after 12096 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15200 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.001251 after 12160 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15280 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.001317 after 12224 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15360 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.001615 after 12288 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15440 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.001579 after 12352 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15520 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.001533 after 12416 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15600 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.000997 after 12480 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15680 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.001010 after 12544 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15760 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.001155 after 12608 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15840 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.000945 after 12672 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15920 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.000992 after 12736 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.018614 after 15920 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 15920 accepted steps.

# %%
# 🚀 Export results to GetDist
gd_sample = sampler.products(to_getdist=True)["sample"]

# 📊 Quick stats
mean   = gd_sample.getMeans()[:]
covmat = gd_sample.getCovMat().matrix[:, :]
corrmat = covmat / np.outer(np.sqrt(np.diag(covmat)), np.sqrt(np.diag(covmat)))

print("✨ Posterior Means:")
print(mean)
print("\n🧩 Covariance Matrix:")
print(covmat)
print("\n🔗 Correlation Matrix:")
print(corrmat)

# 🎨 Plot with GetDist
# %matplotlib inline  # (uncomment when running in Jupyter)
import getdist.plots as gdplt

gdplot = gdplt.get_subplot_plotter()
gdplot.triangle_plot(gd_sample, ["H0", "M"], filled=True)

# 🔥 Boom! Your posteriors are ready.
# Out:
# [mcmc] *WARNING* When combining chains, it is recommended to remove some initial fraction, e.g. 'skip_samples=0.3'
# ✨ Posterior Means:
# [ 73.09283719 -19.2987748    2.09718773   2.09718773 221.96394558
#  221.96394558]
#
# 🧩 Covariance Matrix:
# [[2.89289040e+00 8.17115130e-02]
#  [8.17115130e-02 2.42400899e-03]]
#
# 🔗 Correlation Matrix:
# [[1.         0.97577604]
#  [0.97577604 1.        ]]

# %%
# 🎯 Plot marginal posterior of H0 from Cobaya
samples = sampler.products(skip_samples=0.3)['sample']  

plt.figure()

# Histogram normalized to density
hist = sns.histplot(samples['H0'], bins=30, kde=True, stat="density", color="steelblue", alpha=0.5, label="Cobaya samples")

# Compute scaling factor so the analytic posterior matches histogram peak
scale_factor = hist.get_lines()[0].get_ydata().max() / pH0.max()

# Overlay analytic posterior, rescaled to same max height
plt.plot(H0_grid, pH0 * scale_factor, color='black', lw=3, ls ='--', label='$p(H_0|data)$ from grid')

plt.xlabel(r'$H_0$ [km/s/Mpc]')
plt.ylabel('Normalized Density (matched peaks)')
plt.title('Comparison of Cobaya MCMC samples and grid-like marginalised posterior')
plt.xlim(65, 81)
plt.legend()
plt.show()

# ATTENTION: The following plot do not match because:
# The grid-like posterior is computed with a really simple grid, 
# not the full MCMC exploration

# %% [markdown]
# ## (*) Ideas to follow up!
# - Include an intrinsic scatter parameter $\sigma_\mathrm{int}$ and either tune it to make $\chi^2_\nu\approx1$ or infer it with a prior (e.g., Jeffreys prior on a scale).
# - Replace the low-$z$ approximation with full $d_L(z; H_0, \Omega_m, \Omega_\Lambda, w,...)$ to use higher-$z$ SNe.
# - Incorporate selection effects and Malmquist bias corrections for realistic samples.
